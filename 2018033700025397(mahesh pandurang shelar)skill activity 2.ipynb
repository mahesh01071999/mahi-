# %% [markdown]
# # <center>SKILL ACTIVITY NO:02</center>
# <span style="float:right">Date:25/07/2021</span>
# Name:Mahesh Pandurang Shelar<br>
# <br>
# PRN:2018033700025397<br>
# <br>
# School:Symboisis Skill and Professional University,Pune <br>
# <br>
# Program: Machine Learning & Artificial Intelligence Analyst<br>
# <br>
# Batch: ML11<br>
# <br>
# Module Name: Python Programming<br>
# <br>
# Module Code: ML11<br>
# <br>
# ####Title: Perform Regression on the Toyota Corolla Data Set. Use appropriate libraries<br>
#
# ####Skills/Competencies to be acquired:<br>
# 1.	To gain an understanding of data and find clues from the data.
# 2.	Assess assumptions on which statistical inference will be based.
# 3.	To check the quality of data for further processing and cleaning if necessary.
# 4.	To check for outliers that may impact model.
# 5.	Data Visualization.
# 6.  scaling the data
# 7.  classify data into training and testing
# 8.  machine learning regression models
#
# ####Duration of activity: 2 to 3 Hour<brs>
#
# ##### 1.What is the purpose of this activity?<br>
#
# 1)Preview data.<br>
# 2)Check total number of entries and column types.<br>
# 3)Check any null values.<br>
# 4)Check duplicate entries.<br>
# 5)Plot distribution of numeric data.<br>
# 6)Plot count distribution of categorical data.<br>
# 7)prepare a prediction model for predicting Price.<br>
# ##### 2.Steps performed in this activity.<br>
# 1)import all necessary libraries.<br>
# 2)read dataset using pandas.<br>
# 3)check the null valus,duplicates,type of datacolumns etc.<br>
# 4)check statistics of dataset.<br>
# 5)check for outliers and then removed outliers.<br>
# 6)check for correlation.<br>
# 7)data visualization.<br>
# 8)seperate target column.<br>
# 9)splitting the data into training and testing.<br>
# 10)scaling.<br>
# 11)used different machine learning algorithms and evaluation for checking accuracy.<br>
#
# ##### 3.What resources / materials / equipment / tools did you use for this activity?<br>
# 1)Jupyter Notebook<br>
#
# ##### 4.What skills did you acquire?<br>
# 1)data cleaning<br>
# 2)data visualization<br>
# 3)exploratory data analysis<br>
# 4)data preprocessing<br>
# 5)python<br>
# 6)Machine Learning<br>
#
#
# ##### 5.Time taken to complete the activity?<br>
# 2 to 3hours<br>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/Expert/Downloads/ToyotaCorolla.csv - ToyotaCorolla.csv.csv")

# %%
df.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3  ?TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ...  Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...             1
# 1         10      2002  72937    Diesel  90          1  ...             1
# 2          9      2002  41711    Diesel  90          1  ...             0
# 3          7      2002  48000    Diesel  90          0  ...             0
# 4          3      2002  38500    Diesel  90          0  ...             1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Model', 'Price', 'Age_08_04', 'Mfg_Month', 'Mfg_Year', 'KM',
#        'Fuel_Type', 'HP', 'Met_Color', 'Automatic', 'cc', 'Doors', 'Cylinders',
#        'Gears', 'Quarterly_Tax', 'Weight', 'Mfr_Guarantee', 'BOVAG_Guarantee',
#        'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2', 'Airco',
#        'Automatic_airco', 'Boardcomputer', 'CD_Player', 'Central_Lock',
#        'Powered_Windows', 'Power_Steering', 'Radio', 'Mistlamps',
#        'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
#        'Tow_Bar'],
#       dtype='object')

# %%
df=df.drop(columns=['Id', 'Model', 'Mfg_Month', 'Mfg_Year','Fuel_Type', 'Met_Color', 'Automatic', 'Cylinders','Mfr_Guarantee', 'BOVAG_Guarantee','Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2', 'Airco','Automatic_airco', 'Boardcomputer', 'CD_Player', 'Central_Lock','Powered_Windows', 'Power_Steering', 'Radio', 'Mistlamps','Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette','Tow_Bar'])

# %%
df.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %%
df.isna().sum()
# Out:
# Price            0
# Age_08_04        0
# KM               0
# HP               0
# cc               0
# Doors            0
# Gears            0
# Quarterly_Tax    0
# Weight           0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1431    False
# 1432    False
# 1433    False
# 1434    False
# 1435    False
# Length: 1436, dtype: bool

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP           cc  \
# count   1436.000000  1436.000000    1436.000000  1436.000000   1436.00000
# mean   10730.824513    55.947075   68533.259749   101.502089   1576.85585
# std     3626.964585    18.599988   37506.448872    14.981080    424.38677
# min     4350.000000     1.000000       1.000000    69.000000   1300.00000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.00000
# 50%     9900.000000    61.000000   63389.500000   110.000000   1600.00000
# 75%    11950.000000    70.000000   87020.750000   110.000000   1600.00000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.00000
#
#              Doors        Gears  Quarterly_Tax      Weight
# count  1436.000000  1436.000000    1436.000000  1436.00000
# mean      4.033426     5.026462      87.122563  1072.45961
# std       0.952677     0.188510      41.128611    52.64112
# min       2.000000     3.000000      19.000000  1000.00000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1436 non-null   int64
#  1   Age_08_04      1436 non-null   int64
#  2   KM             1436 non-null   int64
#  3   HP             1436 non-null   int64
#  4   cc             1436 non-null   int64
#  5   Doors          1436 non-null   int64
#  6   Gears          1436 non-null   int64
#  7   Quarterly_Tax  1436 non-null   int64
#  8   Weight         1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %%
sns.catplot("Gears",kind="count",data=df)

# %%
sns.boxplot(data=df)

# %%
df.boxplot()

# %%
#remove outliers by using IQR method

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1

# %%
IQR
# Out:
# Price             3500.00
# Age_08_04           26.00
# KM               44020.75
# HP                  20.00
# cc                 200.00
# Doors                2.00
# Gears                0.00
# Quarterly_Tax       16.00
# Weight              45.00
# dtype: float64

# %%
o_df=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
o_df.shape
# Out:
# (1068, 9)

# %%
o_df.boxplot()

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000226E83274F0>,
# ...
#       dtype=object)

# %%
df.plot(subplots=True,figsize=(20,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000226EA79ACA0>,
# ...
#       dtype=object)

# %%
df.corr()
# Out:
#                   Price  Age_08_04        KM        HP        cc     Doors  \
# Price          1.000000  -0.876590 -0.569960  0.314990  0.126389  0.185326
# Age_08_04     -0.876590   1.000000  0.505672 -0.156622 -0.098084 -0.148359
# KM            -0.569960   0.505672  1.000000 -0.333538  0.102683 -0.036197
# HP             0.314990  -0.156622 -0.333538  1.000000  0.035856  0.092424
# cc             0.126389  -0.098084  0.102683  0.035856  1.000000  0.079903
# Doors          0.185326  -0.148359 -0.036197  0.092424  0.079903  1.000000
# Gears          0.063104  -0.005364  0.015023  0.209477  0.014629 -0.160141
# Quarterly_Tax  0.219197  -0.198431  0.278165 -0.298432  0.306996  0.109363
# Weight         0.581198  -0.470253 -0.028598  0.089614  0.335637  0.302618
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063104       0.219197  0.581198
# Age_08_04     -0.005364      -0.198431 -0.470253
# KM             0.015023       0.278165 -0.028598
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)

# %%
df.dtypes
# Out:
# Price            int64
# Age_08_04        int64
# KM               int64
# HP               int64
# cc               int64
# Doors            int64
# Gears            int64
# Quarterly_Tax    int64
# Weight           int64
# dtype: object

# %%
x=df.drop(columns="Price")
y=df["Price"]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
import statsmodels.api as sm

# %%
#adding a constant to get an intercept

# %%
Xtrain_sm = sm.add_constant(xtrain)

# %%
# Fitting the resgression line using 'OLS'
lr = sm.OLS(ytrain, Xtrain_sm).fit()
# Printing the parameters
lr.params
# Out:
# const           -6927.799789
# Age_08_04        -121.138340
# KM                 -0.018401
# HP                 33.229416
# cc                 -2.002937
# Doors             -28.196746
# Gears             609.551830
# Quarterly_Tax       7.279838
# Weight             20.416253
# dtype: float64

# %%
# Performing a summary to list out all the different parameters of the regression line fitted
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.873
# Method:                 Least Squares   F-statistic:                     985.7
# Date:                Mon, 26 Jul 2021   Prob (F-statistic):               0.00
# Time:                        10:58:23   Log-Likelihood:                -9857.3
# No. Observations:                1148   AIC:                         1.973e+04
# Df Residuals:                    1139   BIC:                         1.978e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
#scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(xtrain)
sc_xtrain=sc.fit_transform(xtrain)
sc_xtest=sc.fit_transform(xtest)

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(sc_xtrain,ytrain)
ypred=lr.predict(sc_xtest)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
score=r2_score(ytest,ypred)
rmse=np.sqrt(mse)
print("MSE:",mse)
print("MAE:",mae)
print("accuracy is:",score)
print("RMSE:",rmse)
# Out:
# MSE: 2412635.263425067
# MAE: 1104.7067668868706
# accuracy is: 0.8060939424828726
# RMSE: 1553.2659989277647

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge
model=Ridge(alpha=0.1)
model.fit(sc_xtrain,ytrain)
ridge_ypred=model.predict(sc_xtest)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
score=r2_score(ytest,ypred)
rmse=np.sqrt(mse)
print("MSE:",mse)
print("MAE:",mae)
print("accuracy is:",score)
print("RMSE:",rmse)
# Out:
# MSE: 2412635.263425067
# MAE: 1104.7067668868706
# accuracy is: 0.8060939424828726
# RMSE: 1553.2659989277647

# %%
print("ridge coefficients:",model.coef_)
# Out:
# ridge coefficients: [-2258.03886382  -691.92112883   483.79490408  -376.63421796
#    -26.79771245   119.56546751   300.35797617  1098.55656886]

# %% [markdown]
# # Lasso model

# %%
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=0.1)
model.fit(sc_xtrain,ytrain)
ridge_ypred=model.predict(sc_xtest)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
score=r2_score(ytest,ypred)
rmse=np.sqrt(mse)
print("MSE:",mse)
print("MAE:",mae)
print("accuracy is:",score)
print("RMSE:",rmse)
# Out:
# MSE: 2412635.263425067
# MAE: 1104.7067668868706
# accuracy is: 0.8060939424828726
# RMSE: 1553.2659989277647

# %% [markdown]
# # ElasticNet

# %%
from sklearn.linear_model import ElasticNet
model=ElasticNet(alpha=1.5)
model.fit(sc_xtrain,ytrain)
ypred=model.predict(sc_xtest)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
score=r2_score(ytest,ypred)
rmse=np.sqrt(mse)
print("MSE:",mse)
print("MAE:",mae)
print("accuracy is:",score)
print("RMSE:",rmse)
# Out:
# MSE: 2874621.3759323265
# MAE: 1226.5914091451461
# accuracy is: 0.7689636281490048
# RMSE: 1695.4708419587541

# %% [markdown]
# # ElasticNetCV

# %%
from sklearn.linear_model import ElasticNetCV
model=ElasticNetCV(cv=5)
model.fit(sc_xtrain,ytrain)
ypred=model.predict(sc_xtest)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
score=r2_score(ytest,ypred)
rmse=np.sqrt(mse)
print("MSE:",mse)
print("MAE:",mae)
print("accuracy is:",score)
print("RMSE:",rmse)
# Out:
# MSE: 6078297.964905671
# MAE: 1806.490643077187
# accuracy is: 0.5114807394815135
# RMSE: 2465.4204438402935

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(sc_xtrain,ytrain)
ypred=model.predict(sc_xtest)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
score=r2_score(ytest,ypred)
rmse=np.sqrt(mse)
print("MSE:",mse)
print("MAE:",mae)
print("accuracy is:",score)
print("RMSE:",rmse)
# Out:
# MSE: 3458726.048611111
# MAE: 1382.6805555555557
# accuracy is: 0.7220185154858975
# RMSE: 1859.765051992082

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=50)
model.fit(sc_xtrain,ytrain)
ypred=model.predict(sc_xtest)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
score=r2_score(ytest,ypred)
rmse=np.sqrt(mse)
print("MSE:",mse)
print("MAE:",mae)
print("accuracy is:",score)
print("RMSE:",rmse)
# Out:
# MSE: 1683165.9856449077
# MAE: 976.3599305555557
# accuracy is: 0.8647221627856014
# RMSE: 1297.3688703082512

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVR
model=SVR()
model.fit(sc_xtrain,ytrain)
ypred=model.predict(sc_xtest)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
score=r2_score(ytest,ypred)
rmse=np.sqrt(mse)
print("MSE:",mse)
print("MAE:",mae)
print("accuracy is:",score)
print("RMSE:",rmse)
# Out:
# MSE: 12883194.91793894
# MAE: 2464.5906627671775
# accuracy is: -0.03543605311305709
# RMSE: 3589.316775925321

# %% [markdown]
# # AdaBoostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
model=AdaBoostRegressor(n_estimators=50)
model.fit(sc_xtrain,ytrain)
ypred=model.predict(sc_xtest)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
score=r2_score(ytest,ypred)
rmse=np.sqrt(mse)
print("MSE:",mse)
print("MAE:",mae)
print("accuracy is:",score)
print("RMSE:",rmse)
# Out:
# MSE: 1922740.0552741226
# MAE: 1052.7000549777824
# accuracy is: 0.8454673404635626
# RMSE: 1386.6290258299523

# %% [markdown]
# # GradientBoostingRegresor

# %%
from sklearn.ensemble import GradientBoostingRegressor
model=GradientBoostingRegressor(n_estimators=50)
model.fit(sc_xtrain,ytrain)
ypred=model.predict(sc_xtest)

# %% [markdown]
# # Evaluation

# %%
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
score=r2_score(ytest,ypred)
rmse=np.sqrt(mse)
print("MSE:",mse)
print("MAE:",mae)
print("accuracy is:",score)
print("RMSE:",rmse)
# Out:
# MSE: 1555882.108098062
# MAE: 944.0188212306906
# accuracy is: 0.8749521031561004
# RMSE: 1247.3500343119656

# %%
model.score(sc_xtrain,ytrain)
# Out:
# 0.9384730895023281

# %%
model=["Linear Regression","Ridge Regression","Lasso","ElasticNet","ElasticNetCV","DecisionTreeRegressor","RandomForestRegressor","SVR","AdaBoostRegressor","GradientBoostingRegresor"]
r2_score=[0.8060939424828726,0.8060939424828726,0.8060939424828726,0.7689636281490048,0.5114807394815135, 0.773816254603607, 0.8636054564727467,-0.03543605311305709, 0.8359052152315862, 0.8743306664043184]
dict=({"Regression models":model,"r2_score":r2_score})
result=pd.DataFrame(dict)
result
# Out:
#           Regression models  r2_score
# 0         Linear Regression  0.806094
# 1          Ridge Regression  0.806094
# 2                     Lasso  0.806094
# 3                ElasticNet  0.768964
# 4              ElasticNetCV  0.511481
# 5     DecisionTreeRegressor  0.773816
# 6     RandomForestRegressor  0.863605
# 7                       SVR -0.035436
# 8         AdaBoostRegressor  0.835905
# 9  GradientBoostingRegresor  0.874331
